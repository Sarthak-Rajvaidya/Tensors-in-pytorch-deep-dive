# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarthak-Rajvaidya/Tensors-in-pytorch-deep-dive/blob/main/tesnors_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
#To check is GPU is available or not
if torch.cuda.is_available():
  print("GPU is available")
  print(f"USing GPU:{torch.cuda.get_device_name(0)}")
else:
  print("GPU not available. Using CPU")
# Out:
# GPU is available
# USing GPU:Tesla T4

# %% [markdown]
# CREATING A **TENSOR** **bold text**

# %%
#uisng empty
a =torch.empty(2,3)

# %%
#check type
type(a)
# Out:
# torch.Tensor

# %%
#using zeros

torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
#using ones
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
#using rand - To create random values in between 0 to 1
torch.rand(2,3)
# Out:
# tensor([[0.8208, 0.7940, 0.7279],
#         [0.2166, 0.9555, 0.5319]])

# %%
#manual seed:- to get same random valus for differnet users:-\
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
#using tensor - custom apne manapasand
torch.tensor([[1,2,3],[4,5,6]])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %% [markdown]
# **TENSORS** **SHAPE**

# %%
x = torch.tensor([[1,2,3],[4,5,6]])
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# **TENSORS DATATYPE**

# %%
x.dtype
# Out:
# torch.int64

# %%
#assign data type
torch.tensor([1.0,2.0,3.0],dtype = torch.int32)
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
torch.tensor([1,2,3],dtype=torch.float64)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
#Change data typ of existing data type
x.to(torch.float32)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %% [markdown]
# **Mathematicals opeartions :-**

# %% [markdown]
# 1.Sclar Opeartion

# %%
x=torch.rand(2,2)

# %%
x
# Out:
# tensor([[0.2627, 0.0428],
#         [0.2080, 0.1180]])

# %%
#addition
x+1
# Out:
# tensor([[1.2627, 1.0428],
#         [1.2080, 1.1180]])
